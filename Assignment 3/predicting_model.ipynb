# %%
import os
spark_home = os.path.abspath(os.getcwd() + "/../spark-3.5.5-bin-hadoop3")
os.environ["SPARK_HOME"] = spark_home
print(f"SPARK_HOME set to: {spark_home}")

if os.name == 'nt':
    hadoop_home = os.path.abspath(os.getcwd() + "/../winutils")
    os.environ["HADOOP_HOME"] = hadoop_home
    print(f"HADOOP_HOME set to: {hadoop_home}")
    hadoop_bin = os.path.join(hadoop_home, "bin")
    os.environ["PATH"] = f"{hadoop_bin};{os.environ['PATH']}"
    print(f"Added Hadoop bin to PATH: {hadoop_bin}")

import findspark
findspark.init(spark_home)

import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf, from_json, schema_of_json
from pyspark.sql.types import ArrayType, StringType

spark = SparkSession.builder.appName("ArxivCategoryPrediction").getOrCreate()
sc = spark.sparkContext
print("SparkSession and SparkContext initialized successfully.")
# Out:
# SPARK_HOME set to: C:\spark_project\spark\spark-3.5.5-bin-hadoop3
# HADOOP_HOME set to: C:\spark_project\spark\winutils
# Added Hadoop bin to PATH: C:\spark_project\spark\winutils\bin
# SparkSession and SparkContext initialized successfully.

# %%
import torch
from transformers import AutoTokenizer, AutoModel
import joblib

tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
scibert = AutoModel.from_pretrained("allenai/scibert_scivocab_uncased").eval()
clf = joblib.load("cleaned_classifier.pkl")
mlb = joblib.load("label_binarizer.pkl")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
scibert.to(device)

def predict_labels(title, summary, threshold=0.4):
    text = f"{title.strip()} {summary.strip()}"
    with torch.no_grad():
        tokens = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
        tokens = {k: v.to(device) for k, v in tokens.items()}
        outputs = scibert(**tokens)
        cls_embedding = outputs.last_hidden_state[:, 0, :].cpu().numpy()
    proba = clf.predict_proba(cls_embedding)[0]
    labels = [label for label, p in zip(mlb.classes_, proba) if p >= threshold]
    return labels

predict_udf = udf(lambda title, summary: predict_labels(title, summary), ArrayType(StringType()))
# Out:
# C:\spark_project\spark\.pixi\envs\default\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %%
host = "seppe.net"
port = 7778

raw_stream = spark.readStream \
    .format("socket") \
    .option("host", host) \
    .option("port", port) \
    .load()

# %%
# Defining schema using a sample JSON
sample_json = """
{
  "aid": "http://arxiv.org/abs/2503.19871v1",
  "title": "A natural MSSM from a novel $\\\\mathsf{SO(10)}$ [...]",
  "summary": "The $\\\\mathsf{SO(10)}$ model [...]",
  "main_category": "hep-ph",
  "categories": "hep-ph,hep-ex",
  "published": "2025-03-25T17:36:54Z"
}
"""

schema = schema_of_json(sample_json)

parsed_stream = raw_stream \
    .select(from_json(col("value"), schema).alias("json")) \
    .select("json.*")

# %%
import json

def process_batch(batch_df, batch_id):
    print(f"Processing batch_id: {batch_id} with {batch_df.count()} records.")
    pdf = batch_df.toPandas()

    predictions = []

    for _, row in pdf.iterrows():
        predicted = predict_labels(row["title"], row["summary"])
        predictions.append(json.dumps(predicted))

    pdf["predicted_labels"] = predictions

    print(pdf[["aid", "predicted_labels"]])

query = parsed_stream.writeStream \
    .foreachBatch(process_batch) \
    .start()

query.awaitTermination()
# Out:
# Processing batch_id: 0 with 0 records.
# Empty DataFrame
# Columns: [aid, predicted_labels]
# Index: []
# Processing batch_id: 1 with 8 records.
#                                  aid predicted_labels
# 0  http://arxiv.org/abs/2505.20078v1    ["gr", "hep"]
# 1  http://arxiv.org/abs/2505.20079v1           ["cs"]
# 2  http://arxiv.org/abs/2505.20080v1         ["math"]
# 3  http://arxiv.org/abs/2505.20081v1           ["cs"]
# 4  http://arxiv.org/abs/2505.20082v1           ["cs"]
# 5  http://arxiv.org/abs/2505.20083v1         ["math"]
# 6  http://arxiv.org/abs/2505.20084v1    ["gr", "hep"]
# 7  http://arxiv.org/abs/2505.20085v1           ["cs"]
# Processing batch_id: 2 with 7 records.
#                                  aid     predicted_labels
# 0  http://arxiv.org/abs/2505.20086v1                   []
# 1  http://arxiv.org/abs/2505.20087v1               ["cs"]
# 2  http://arxiv.org/abs/2505.20088v1               ["cs"]
# 3  http://arxiv.org/abs/2505.20089v1               ["cs"]
# 4  http://arxiv.org/abs/2505.20090v1       ["cs", "eess"]
# 5  http://arxiv.org/abs/2505.20091v1             ["math"]
# 6  http://arxiv.org/abs/2505.20092v1  ["cond", "physics"]
# Processing batch_id: 3 with 9 records.
#                                  aid     predicted_labels
# 0  http://arxiv.org/abs/2505.20093v1  ["eess", "physics"]
# 1  http://arxiv.org/abs/2505.20101v1               ["cs"]
# 2  http://arxiv.org/abs/2505.20094v1               ["cs"]
# 3  http://arxiv.org/abs/2505.20095v1               ["cs"]
# 4  http://arxiv.org/abs/2505.20096v1               ["cs"]
# 5  http://arxiv.org/abs/2505.20097v1               ["cs"]
# 6  http://arxiv.org/abs/2505.20098v1               ["cs"]
# 7  http://arxiv.org/abs/2505.20099v1               ["cs"]
# 8  http://arxiv.org/abs/2505.20100v1               ["cs"]
# Processing batch_id: 4 with 11 records.
#                                   aid      predicted_labels
# 0   http://arxiv.org/abs/2505.20102v1              ["math"]
# 1   http://arxiv.org/abs/2505.20110v1                ["cs"]
# 2   http://arxiv.org/abs/2505.20103v1                ["cs"]
# 3   http://arxiv.org/abs/2505.20111v1              ["stat"]
# 4   http://arxiv.org/abs/2505.20104v1  ["physics", "quant"]
# 5   http://arxiv.org/abs/2505.20112v1                ["cs"]
# 6   http://arxiv.org/abs/2505.20105v1             ["astro"]
# 7   http://arxiv.org/abs/2505.20106v1                ["cs"]
# 8   http://arxiv.org/abs/2505.20107v1        ["cs", "eess"]
# 9   http://arxiv.org/abs/2505.20108v1             ["quant"]
# 10  http://arxiv.org/abs/2505.20109v1                ["cs"]
# Processing batch_id: 5 with 11 records.
#                                   aid   predicted_labels
# 0   http://arxiv.org/abs/2505.20113v1             ["cs"]
# 1   http://arxiv.org/abs/2505.20121v1             ["cs"]
# 2   http://arxiv.org/abs/2505.20114v1  ["cs", "physics"]
# 3   http://arxiv.org/abs/2505.20122v1             ["cs"]
# 4   http://arxiv.org/abs/2505.20115v1                 []
# 5   http://arxiv.org/abs/2505.20123v1     ["cs", "stat"]
# 6   http://arxiv.org/abs/2505.20116v1           ["cond"]
# 7   http://arxiv.org/abs/2505.20117v1           ["math"]
# 8   http://arxiv.org/abs/2505.20118v1             ["cs"]
# 9   http://arxiv.org/abs/2505.20119v1             ["cs"]
# 10  http://arxiv.org/abs/2505.20120v1        ["cs", "q"]
# Processing batch_id: 6 with 10 records.
#                                  aid  predicted_labels
# 0  http://arxiv.org/abs/2505.20124v1            ["cs"]
# 1  http://arxiv.org/abs/2505.20132v1            ["cs"]
# 2  http://arxiv.org/abs/2505.20125v1  ["hep", "quant"]
# 3  http://arxiv.org/abs/2505.20133v1            ["cs"]
# 4  http://arxiv.org/abs/2505.20126v1            ["cs"]
# 5  http://arxiv.org/abs/2505.20127v1            ["cs"]
# 6  http://arxiv.org/abs/2505.20128v1            ["cs"]
# 7  http://arxiv.org/abs/2505.20129v1            ["cs"]
# 8  http://arxiv.org/abs/2505.20130v1    ["cs", "stat"]
# 9  http://arxiv.org/abs/2505.20131v1            ["cs"]
# Processing batch_id: 7 with 12 records.
#                                   aid         predicted_labels
# 0   http://arxiv.org/abs/2505.20134v1                 ["math"]
# 1   http://arxiv.org/abs/2505.20142v1                   ["cs"]
# 2   http://arxiv.org/abs/2505.20135v1                   ["cs"]
# 3   http://arxiv.org/abs/2505.20143v1                ["astro"]
# 4   http://arxiv.org/abs/2505.20136v1                   ["cs"]
# 5   http://arxiv.org/abs/2505.20144v1                   ["cs"]
# 6   http://arxiv.org/abs/2505.20137v1                   ["cs"]
# 7   http://arxiv.org/abs/2505.20145v1                 ["cond"]
# 8   http://arxiv.org/abs/2505.20138v1                   ["cs"]
# 9   http://arxiv.org/abs/2505.20139v1                   ["cs"]
# 10  http://arxiv.org/abs/2505.20140v1  ["hep", "physics", "q"]
# 11  http://arxiv.org/abs/2505.20141v1      ["cond", "physics"]
# Processing batch_id: 8 with 12 records.
#                                   aid        predicted_labels
# 0   http://arxiv.org/abs/2505.20146v1          ["cs", "eess"]
# 1   http://arxiv.org/abs/2505.20154v1                  ["cs"]
# 2   http://arxiv.org/abs/2505.20147v1                  ["cs"]
# 3   http://arxiv.org/abs/2505.20155v1                  ["cs"]
# 4   http://arxiv.org/abs/2505.20148v1                  ["cs"]
# 5   http://arxiv.org/abs/2505.20156v1                  ["cs"]
# 6   http://arxiv.org/abs/2505.20149v1          ["cs", "math"]
# 7   http://arxiv.org/abs/2505.20157v1        ["math", "stat"]
# 8   http://arxiv.org/abs/2505.20150v1          ["cs", "math"]
# 9   http://arxiv.org/abs/2505.20151v1                ["stat"]
# 10  http://arxiv.org/abs/2505.20152v1                  ["cs"]
# 11  http://arxiv.org/abs/2505.20153v1  ["cs", "math", "stat"]
# Processing batch_id: 9 with 12 records.
#                                   aid        predicted_labels
# 0   http://arxiv.org/abs/2505.20158v1                  ["cs"]
# 1   http://arxiv.org/abs/2505.20166v1                  ["cs"]
# 2   http://arxiv.org/abs/2505.20159v1                ["cond"]
# 3   http://arxiv.org/abs/2505.20167v1  ["astro", "gr", "hep"]
# 4   http://arxiv.org/abs/2505.20160v1          ["cs", "math"]
# 5   http://arxiv.org/abs/2505.20168v1                ["stat"]
# 6   http://arxiv.org/abs/2505.20161v1                  ["cs"]
# 7   http://arxiv.org/abs/2505.20169v1             ["physics"]
# 8   http://arxiv.org/abs/2505.20162v1                  ["cs"]
# 9   http://arxiv.org/abs/2505.20163v1          ["cs", "eess"]
# 10  http://arxiv.org/abs/2505.20164v1                  ["cs"]
# 11  http://arxiv.org/abs/2505.20165v1               ["astro"]
# Processing batch_id: 10 with 15 records.
#                                   aid  predicted_labels
# 0   http://arxiv.org/abs/2505.20170v1            ["cs"]
# 1   http://arxiv.org/abs/2505.20178v1            ["cs"]
# 2   http://arxiv.org/abs/2505.20171v1            ["cs"]
# 3   http://arxiv.org/abs/2505.20179v1         ["astro"]
# 4   http://arxiv.org/abs/2505.20172v1    ["cs", "stat"]
# 5   http://arxiv.org/abs/2505.20180v1   ["cond", "hep"]
# 6   http://arxiv.org/abs/2505.20173v1         ["astro"]
# 7   http://arxiv.org/abs/2505.20181v1            ["cs"]
# 8   http://arxiv.org/abs/2505.20174v1  ["math", "nlin"]
# 9   http://arxiv.org/abs/2505.20182v1            ["cs"]
# 10  http://arxiv.org/abs/2505.20175v1            ["cs"]
# 11  http://arxiv.org/abs/2505.20183v1            ["cs"]
# 12  http://arxiv.org/abs/2505.20176v1            ["cs"]
# 13  http://arxiv.org/abs/2505.20184v1            ["cs"]
# 14  http://arxiv.org/abs/2505.20177v1    ["cs", "stat"]
# Processing batch_id: 11 with 16 records.
#                                   aid              predicted_labels
# 0   http://arxiv.org/abs/2505.20185v1             ["cs", "physics"]
# 1   http://arxiv.org/abs/2505.20193v1               ["astro", "gr"]
# 2   http://arxiv.org/abs/2505.20186v1                        ["cs"]
# 3   http://arxiv.org/abs/2505.20194v1         ["gr", "hep", "math"]
# 4   http://arxiv.org/abs/2505.20187v1  ["cond", "physics", "quant"]
# 5   http://arxiv.org/abs/2505.20195v1                        ["cs"]
# 6   http://arxiv.org/abs/2505.20188v1                        ["cs"]
# 7   http://arxiv.org/abs/2505.20196v1                        ["cs"]
# 8   http://arxiv.org/abs/2505.20189v1                        ["cs"]
# 9   http://arxiv.org/abs/2505.20197v1            ["hep", "physics"]
# 10  http://arxiv.org/abs/2505.20190v1                        ["cs"]
# 11  http://arxiv.org/abs/2505.20198v1                            []
# 12  http://arxiv.org/abs/2505.20191v1         ["gr", "hep", "math"]
# 13  http://arxiv.org/abs/2505.20199v1                        ["cs"]
# 14  http://arxiv.org/abs/2505.20192v1                        ["cs"]
# 15  http://arxiv.org/abs/2505.20200v1                ["cs", "eess"]
# Processing batch_id: 12 with 19 records.
#                                   aid           predicted_labels
# 0   http://arxiv.org/abs/2505.20201v1                     ["cs"]
# 1   http://arxiv.org/abs/2505.20209v1                     ["cs"]
# 2   http://arxiv.org/abs/2505.20217v1                   ["math"]
# 3   http://arxiv.org/abs/2505.20202v1                ["cs", "q"]
# 4   http://arxiv.org/abs/2505.20210v1  ["cs", "math", "physics"]
# 5   http://arxiv.org/abs/2505.20218v1                     ["cs"]
# 6   http://arxiv.org/abs/2505.20203v1                   ["econ"]
# 7   http://arxiv.org/abs/2505.20211v1                     ["cs"]
# 8   http://arxiv.org/abs/2505.20219v1     ["cs", "math", "stat"]
# 9   http://arxiv.org/abs/2505.20204v1          ["cond", "quant"]
# 10  http://arxiv.org/abs/2505.20212v1                   ["math"]
# 11  http://arxiv.org/abs/2505.20205v1                   ["cond"]
# 12  http://arxiv.org/abs/2505.20213v1          ["cond", "quant"]
# 13  http://arxiv.org/abs/2505.20206v1                     ["cs"]
# 14  http://arxiv.org/abs/2505.20214v1                     ["cs"]
# 15  http://arxiv.org/abs/2505.20207v1                     ["cs"]
# 16  http://arxiv.org/abs/2505.20215v1                     ["cs"]
# 17  http://arxiv.org/abs/2505.20208v1          ["cond", "quant"]
# 18  http://arxiv.org/abs/2505.20216v1                     ["cs"]
# Processing batch_id: 13 with 20 records.
#                                   aid           predicted_labels
# 0   http://arxiv.org/abs/2505.20220v1                   ["math"]
# 1   http://arxiv.org/abs/2505.20228v1                   ["cond"]
# 2   http://arxiv.org/abs/2505.20236v1                     ["cs"]
# 3   http://arxiv.org/abs/2505.20221v1             ["cs", "stat"]
# 4   http://arxiv.org/abs/2505.20229v1                     ["cs"]
# 5   http://arxiv.org/abs/2505.20237v1                     ["cs"]
# 6   http://arxiv.org/abs/2505.20222v1             ["cs", "eess"]
# 7   http://arxiv.org/abs/2505.20230v1                     ["cs"]
# 8   http://arxiv.org/abs/2505.20238v1                   ["math"]
# 9   http://arxiv.org/abs/2505.20223v1                     ["cs"]
# 10  http://arxiv.org/abs/2505.20231v1                     ["cs"]
# 11  http://arxiv.org/abs/2505.20239v1             ["cs", "eess"]
# 12  http://arxiv.org/abs/2505.20224v1                   ["math"]
# 13  http://arxiv.org/abs/2505.20232v1                     ["cs"]
# 14  http://arxiv.org/abs/2505.20225v1                     ["cs"]
# 15  http://arxiv.org/abs/2505.20233v1                    ["hep"]
# 16  http://arxiv.org/abs/2505.20226v1  ["cs", "math", "physics"]
# 17  http://arxiv.org/abs/2505.20234v1           ["hep", "quant"]
# 18  http://arxiv.org/abs/2505.20227v1                     ["cs"]
# 19  http://arxiv.org/abs/2505.20235v1             ["cs", "stat"]
# Processing batch_id: 14 with 18 records.
#                                   aid predicted_labels
# 0   http://arxiv.org/abs/2505.20240v1      ["physics"]
# 1   http://arxiv.org/abs/2505.20624v1           ["cs"]
# 2   http://arxiv.org/abs/2505.20632v1         ["math"]
# 3   http://arxiv.org/abs/2505.20241v1           ["cs"]
# 4   http://arxiv.org/abs/2505.20625v1           ["cs"]
# 5   http://arxiv.org/abs/2505.20633v1           ["cs"]
# 6   http://arxiv.org/abs/2505.20242v1           ["cs"]
# 7   http://arxiv.org/abs/2505.20626v1           ["cs"]
# 8   http://arxiv.org/abs/2505.20243v1           ["cs"]
# 9   http://arxiv.org/abs/2505.20627v1   ["cs", "math"]
# 10  http://arxiv.org/abs/2505.20244v1         ["cond"]
# 11  http://arxiv.org/abs/2505.20628v1           ["cs"]
# 12  http://arxiv.org/abs/2505.20245v1           ["cs"]
# 13  http://arxiv.org/abs/2505.20629v1           ["cs"]
# 14  http://arxiv.org/abs/2505.20246v1           ["cs"]
# 15  http://arxiv.org/abs/2505.20630v1           ["cs"]
# 16  http://arxiv.org/abs/2505.20623v1           ["cs"]
# 17  http://arxiv.org/abs/2505.20631v1         ["cond"]
# Processing batch_id: 15 with 20 records.
#                                   aid     predicted_labels
# 0   http://arxiv.org/abs/2505.20634v1               ["cs"]
# 1   http://arxiv.org/abs/2505.20642v1               ["cs"]
# 2   http://arxiv.org/abs/2505.20650v1               ["cs"]
# 3   http://arxiv.org/abs/2505.20635v1               ["cs"]
# 4   http://arxiv.org/abs/2505.20643v1               ["cs"]
# 5   http://arxiv.org/abs/2505.20651v1        ["cond", "q"]
# 6   http://arxiv.org/abs/2505.20636v1  ["eess", "physics"]
# 7   http://arxiv.org/abs/2505.20644v1               ["cs"]
# 8   http://arxiv.org/abs/2505.20652v1             ["math"]
# 9   http://arxiv.org/abs/2505.20637v1               ["cs"]
# 10  http://arxiv.org/abs/2505.20645v1               ["cs"]
# 11  http://arxiv.org/abs/2505.20653v1       ["cs", "stat"]
# 12  http://arxiv.org/abs/2505.20638v1               ["cs"]
# 13  http://arxiv.org/abs/2505.20646v1       ["cs", "stat"]
# 14  http://arxiv.org/abs/2505.20639v1               ["cs"]
# 15  http://arxiv.org/abs/2505.20647v1             ["math"]
# 16  http://arxiv.org/abs/2505.20640v1               ["cs"]
# 17  http://arxiv.org/abs/2505.20648v1               ["cs"]
# 18  http://arxiv.org/abs/2505.20641v1               ["cs"]
# 19  http://arxiv.org/abs/2505.20649v1               ["cs"]
# Processing batch_id: 16 with 20 records.
#                                   aid  predicted_labels
# 0   http://arxiv.org/abs/2505.20654v1            ["cs"]
# 1   http://arxiv.org/abs/2505.20662v1            ["cs"]
# 2   http://arxiv.org/abs/2505.20670v1            ["cs"]
# 3   http://arxiv.org/abs/2505.20655v1            ["cs"]
# 4   http://arxiv.org/abs/2505.20663v1            ["cs"]
# 5   http://arxiv.org/abs/2505.20671v1            ["cs"]
# 6   http://arxiv.org/abs/2505.20656v1         ["astro"]
# 7   http://arxiv.org/abs/2505.20664v1            ["cs"]
# 8   http://arxiv.org/abs/2505.20672v1            ["cs"]
# 9   http://arxiv.org/abs/2505.20657v1          ["math"]
# 10  http://arxiv.org/abs/2505.20665v1            ["cs"]
# 11  http://arxiv.org/abs/2505.20673v1    ["cs", "eess"]
# 12  http://arxiv.org/abs/2505.20658v1            ["cs"]
# 13  http://arxiv.org/abs/2505.20666v1            ["cs"]
# 14  http://arxiv.org/abs/2505.20659v1            ["cs"]
# 15  http://arxiv.org/abs/2505.20667v1            ["cs"]
# 16  http://arxiv.org/abs/2505.20660v1            ["cs"]
# 17  http://arxiv.org/abs/2505.20668v1  ["math", "stat"]
# 18  http://arxiv.org/abs/2505.20661v1           ["hep"]
# 19  http://arxiv.org/abs/2505.20669v1         ["astro"]
# Processing batch_id: 17 with 21 records.
#                                   aid       predicted_labels
# 0   http://arxiv.org/abs/2505.20674v1                 ["cs"]
# 1   http://arxiv.org/abs/2505.20682v1                ["hep"]
# 2   http://arxiv.org/abs/2505.20690v1               ["math"]
# 3   http://arxiv.org/abs/2505.20675v1                 ["cs"]
# 4   http://arxiv.org/abs/2505.20683v1                 ["cs"]
# 5   http://arxiv.org/abs/2505.20691v1                 ["cs"]
# 6   http://arxiv.org/abs/2505.20676v1                 ["cs"]
# 7   http://arxiv.org/abs/2505.20684v1               ["math"]
# 8   http://arxiv.org/abs/2505.20692v1                 ["cs"]
# 9   http://arxiv.org/abs/2505.20677v1  ["cond", "gr", "hep"]
# 10  http://arxiv.org/abs/2505.20685v1         ["cs", "stat"]
# 11  http://arxiv.org/abs/2505.20693v1                 ["cs"]
# 12  http://arxiv.org/abs/2505.20678v1         ["cs", "eess"]
# 13  http://arxiv.org/abs/2505.20686v1                 ["cs"]
# 14  http://arxiv.org/abs/2505.20694v1                 ["cs"]
# 15  http://arxiv.org/abs/2505.20679v1                 ["cs"]
# 16  http://arxiv.org/abs/2505.20687v1                 ["cs"]
# 17  http://arxiv.org/abs/2505.20680v1                 ["cs"]
# 18  http://arxiv.org/abs/2505.20688v1         ["cs", "stat"]
# 19  http://arxiv.org/abs/2505.20681v1               ["stat"]
# 20  http://arxiv.org/abs/2505.20689v1               ["math"]
# Processing batch_id: 18 with 21 records.
#                                   aid      predicted_labels
# 0   http://arxiv.org/abs/2505.20695v1              ["cond"]
# 1   http://arxiv.org/abs/2505.20703v1  ["physics", "quant"]
# 2   http://arxiv.org/abs/2505.20711v1                ["cs"]
# 3   http://arxiv.org/abs/2505.20696v1                ["cs"]
# 4   http://arxiv.org/abs/2505.20704v1                ["cs"]
# 5   http://arxiv.org/abs/2505.20712v1                ["cs"]
# 6   http://arxiv.org/abs/2505.20697v1        ["cs", "stat"]
# 7   http://arxiv.org/abs/2505.20705v1                ["cs"]
# 8   http://arxiv.org/abs/2505.20713v1              ["math"]
# 9   http://arxiv.org/abs/2505.20698v1                ["cs"]
# 10  http://arxiv.org/abs/2505.20706v1             ["astro"]
# 11  http://arxiv.org/abs/2505.20714v1        ["cs", "eess"]
# 12  http://arxiv.org/abs/2505.20699v1              ["math"]
# 13  http://arxiv.org/abs/2505.20707v1                ["cs"]
# 14  http://arxiv.org/abs/2505.20715v1                ["cs"]
# 15  http://arxiv.org/abs/2505.20700v1                ["cs"]
# 16  http://arxiv.org/abs/2505.20708v1        ["cs", "stat"]
# 17  http://arxiv.org/abs/2505.20701v1                ["cs"]
# 18  http://arxiv.org/abs/2505.20709v1              ["math"]
# 19  http://arxiv.org/abs/2505.20702v1              ["nucl"]
# 20  http://arxiv.org/abs/2505.20710v1                ["cs"]
# Processing batch_id: 19 with 23 records.
#                                   aid                   predicted_labels
# 0   http://arxiv.org/abs/2505.20716v1                             ["cs"]
# 1   http://arxiv.org/abs/2505.20724v1  ["astro", "gr", "hep", "physics"]
# 2   http://arxiv.org/abs/2505.20732v1                             ["cs"]
# 3   http://arxiv.org/abs/2505.20717v1                           ["math"]
# 4   http://arxiv.org/abs/2505.20725v1                     ["cs", "stat"]
# 5   http://arxiv.org/abs/2505.20733v1                             ["cs"]
# 6   http://arxiv.org/abs/2505.20718v1                     ["cs", "eess"]
# 7   http://arxiv.org/abs/2505.20726v1                             ["cs"]
# 8   http://arxiv.org/abs/2505.20734v1                             ["cs"]
# 9   http://arxiv.org/abs/2505.20719v1                     ["cs", "math"]
# 10  http://arxiv.org/abs/2505.20727v1                             ["cs"]
# 11  http://arxiv.org/abs/2505.20735v1                           ["math"]
# 12  http://arxiv.org/abs/2505.20720v1                  ["cs", "physics"]
# 13  http://arxiv.org/abs/2505.20728v1                             ["cs"]
# 14  http://arxiv.org/abs/2505.20736v1                    ["astro", "gr"]
# 15  http://arxiv.org/abs/2505.20721v1                  ["cs", "physics"]
# 16  http://arxiv.org/abs/2505.20729v1                             ["cs"]
# 17  http://arxiv.org/abs/2505.20737v1                             ["cs"]
# 18  http://arxiv.org/abs/2505.20722v1            ["astro", "cond", "gr"]
# 19  http://arxiv.org/abs/2505.20730v1                             ["cs"]
# 20  http://arxiv.org/abs/2505.20738v1                             ["cs"]
# 21  http://arxiv.org/abs/2505.20723v1                             ["cs"]
# 22  http://arxiv.org/abs/2505.20731v1                             ["cs"]
# Processing batch_id: 20 with 24 records.
#                                   aid  predicted_labels
# 0   http://arxiv.org/abs/2505.20739v1            ["cs"]
# 1   http://arxiv.org/abs/2505.20747v1    ["cs", "eess"]
# 2   http://arxiv.org/abs/2505.20755v1            ["cs"]
# 3   http://arxiv.org/abs/2505.20740v1            ["cs"]
# 4   http://arxiv.org/abs/2505.20748v1            ["cs"]
# 5   http://arxiv.org/abs/2505.20756v1            ["cs"]
# 6   http://arxiv.org/abs/2505.20741v1            ["cs"]
# 7   http://arxiv.org/abs/2505.20749v1            ["cs"]
# 8   http://arxiv.org/abs/2505.20757v1          ["stat"]
# 9   http://arxiv.org/abs/2505.20742v1            ["cs"]
# 10  http://arxiv.org/abs/2505.20750v1    ["cs", "eess"]
# 11  http://arxiv.org/abs/2505.20758v1          ["math"]
# 12  http://arxiv.org/abs/2505.20743v1            ["cs"]
# 13  http://arxiv.org/abs/2505.20751v1            ["cs"]
# 14  http://arxiv.org/abs/2505.20759v1            ["cs"]
# 15  http://arxiv.org/abs/2505.20744v1            ["cs"]
# 16  http://arxiv.org/abs/2505.20752v1     ["gr", "hep"]
# 17  http://arxiv.org/abs/2505.20760v1    ["cs", "eess"]
# 18  http://arxiv.org/abs/2505.20745v1            ["cs"]
# 19  http://arxiv.org/abs/2505.20753v1            ["cs"]
# 20  http://arxiv.org/abs/2505.20761v1    ["cs", "stat"]
# 21  http://arxiv.org/abs/2505.20746v1            ["cs"]
# 22  http://arxiv.org/abs/2505.20754v1  ["math", "stat"]
# 23  http://arxiv.org/abs/2505.20762v1         ["astro"]
# Processing batch_id: 21 with 24 records.
#                                   aid                predicted_labels
# 0   http://arxiv.org/abs/2505.20763v1                        ["math"]
# 1   http://arxiv.org/abs/2505.20771v1                          ["cs"]
# 2   http://arxiv.org/abs/2505.20779v1                          ["cs"]
# 3   http://arxiv.org/abs/2505.20764v1                          ["cs"]
# 4   http://arxiv.org/abs/2505.20772v1                          ["cs"]
# 5   http://arxiv.org/abs/2505.20780v1                  ["cs", "stat"]
# 6   http://arxiv.org/abs/2505.20765v1                          ["cs"]
# 7   http://arxiv.org/abs/2505.20773v1                          ["cs"]
# 8   http://arxiv.org/abs/2505.20781v1                          ["cs"]
# 9   http://arxiv.org/abs/2505.20766v1                  ["gr", "math"]
# 10  http://arxiv.org/abs/2505.20774v1                          ["cs"]
# 11  http://arxiv.org/abs/2505.20782v1                          ["cs"]
# 12  http://arxiv.org/abs/2505.20767v1                          ["cs"]
# 13  http://arxiv.org/abs/2505.20775v1  ["cs", "eess", "physics", "q"]
# 14  http://arxiv.org/abs/2505.20783v1                          ["cs"]
# 15  http://arxiv.org/abs/2505.20768v1                              []
# 16  http://arxiv.org/abs/2505.20776v1                          ["cs"]
# 17  http://arxiv.org/abs/2505.20784v1                          ["cs"]
# 18  http://arxiv.org/abs/2505.20769v1                          ["cs"]
# 19  http://arxiv.org/abs/2505.20777v1                          ["cs"]
# 20  http://arxiv.org/abs/2505.20785v1                        ["math"]
# 21  http://arxiv.org/abs/2505.20770v1                  ["cs", "eess"]
# 22  http://arxiv.org/abs/2505.20778v1                        ["math"]
# 23  http://arxiv.org/abs/2505.20786v1                        ["math"]
# Processing batch_id: 22 with 24 records.
#                                   aid  predicted_labels
# 0   http://arxiv.org/abs/2505.20787v1  ["math", "stat"]
# 1   http://arxiv.org/abs/2505.20795v1            ["cs"]
# 2   http://arxiv.org/abs/2505.20803v1          ["math"]
# 3   http://arxiv.org/abs/2505.20788v1            ["cs"]
# 4   http://arxiv.org/abs/2505.20796v1                []
# 5   http://arxiv.org/abs/2505.20805v1          ["eess"]
# 6   http://arxiv.org/abs/2505.20789v1            ["cs"]
# 7   http://arxiv.org/abs/2505.20797v1         ["quant"]
# 8   http://arxiv.org/abs/2505.20806v1  ["cond", "math"]
# 9   http://arxiv.org/abs/2505.20790v1          ["cond"]
# 10  http://arxiv.org/abs/2505.20798v1          ["math"]
# 11  http://arxiv.org/abs/2505.20807v1            ["cs"]
# 12  http://arxiv.org/abs/2505.20791v1          ["cond"]
# 13  http://arxiv.org/abs/2505.20799v1          ["math"]
# 14  http://arxiv.org/abs/2505.20808v1            ["cs"]
# 15  http://arxiv.org/abs/2505.20792v1    ["cs", "eess"]
# 16  http://arxiv.org/abs/2505.20800v1   ["cond", "hep"]
# 17  http://arxiv.org/abs/2505.20809v1            ["cs"]
# 18  http://arxiv.org/abs/2505.20793v1            ["cs"]
# 19  http://arxiv.org/abs/2505.20801v1          ["math"]
# 20  http://arxiv.org/abs/2505.20810v1       ["physics"]
# 21  http://arxiv.org/abs/2505.20794v1    ["cs", "eess"]
# 22  http://arxiv.org/abs/2505.20802v1            ["cs"]
# 23  http://arxiv.org/abs/2505.20811v1    ["cs", "math"]
# Processing batch_id: 23 with 23 records.
#                                   aid        predicted_labels
# 0   http://arxiv.org/abs/2505.20812v1         ["hep", "nucl"]
# 1   http://arxiv.org/abs/2505.20820v1                  ["cs"]
# 2   http://arxiv.org/abs/2505.20828v1                  ["cs"]
# 3   http://arxiv.org/abs/2505.20813v1                  ["cs"]
# 4   http://arxiv.org/abs/2505.20821v1               ["astro"]
# 5   http://arxiv.org/abs/2505.20829v1                  ["cs"]
# 6   http://arxiv.org/abs/2505.20814v1                  ["cs"]
# 7   http://arxiv.org/abs/2505.20822v1           ["econ", "q"]
# 8   http://arxiv.org/abs/2505.20830v1                  ["cs"]
# 9   http://arxiv.org/abs/2505.20815v1                  ["cs"]
# 10  http://arxiv.org/abs/2505.20823v1    ["physics", "quant"]
# 11  http://arxiv.org/abs/2505.20831v1  ["cs", "eess", "math"]
# 12  http://arxiv.org/abs/2505.20816v1                  ["cs"]
# 13  http://arxiv.org/abs/2505.20824v1                  ["cs"]
# 14  http://arxiv.org/abs/2505.20832v1               ["quant"]
# 15  http://arxiv.org/abs/2505.20817v1  ["cs", "math", "stat"]
# 16  http://arxiv.org/abs/2505.20825v1                  ["cs"]
# 17  http://arxiv.org/abs/2505.20833v1                      []
# 18  http://arxiv.org/abs/2505.20818v1          ["cs", "math"]
# 19  http://arxiv.org/abs/2505.20826v1                  ["cs"]
# 20  http://arxiv.org/abs/2505.20834v1                  ["cs"]
# 21  http://arxiv.org/abs/2505.20819v1                  ["cs"]
# 22  http://arxiv.org/abs/2505.20827v1                  ["cs"]
# Processing batch_id: 24 with 25 records.
#                                   aid predicted_labels
# 0   http://arxiv.org/abs/2505.20835v1           ["cs"]
# 1   http://arxiv.org/abs/2505.20843v1         ["cond"]
# 2   http://arxiv.org/abs/2505.20851v1   ["cs", "math"]
# 3   http://arxiv.org/abs/2505.20859v1      ["physics"]
# 4   http://arxiv.org/abs/2505.20836v1           ["cs"]
# 5   http://arxiv.org/abs/2505.20844v1        ["quant"]
# 6   http://arxiv.org/abs/2505.20852v1         ["math"]
# 7   http://arxiv.org/abs/2505.20837v1         ["cond"]
# 8   http://arxiv.org/abs/2505.20845v1           ["cs"]
# 9   http://arxiv.org/abs/2505.20853v1           ["cs"]
# 10  http://arxiv.org/abs/2505.20838v1               []
# 11  http://arxiv.org/abs/2505.20846v1               []
# 12  http://arxiv.org/abs/2505.20854v1           ["cs"]
# 13  http://arxiv.org/abs/2505.20839v1           ["cs"]
# 14  http://arxiv.org/abs/2505.20847v1           ["cs"]
# 15  http://arxiv.org/abs/2505.20855v1           ["cs"]
# 16  http://arxiv.org/abs/2505.20840v1           ["cs"]
# 17  http://arxiv.org/abs/2505.20848v1           ["cs"]
# 18  http://arxiv.org/abs/2505.20856v1         ["math"]
# 19  http://arxiv.org/abs/2505.20841v1           ["cs"]
# 20  http://arxiv.org/abs/2505.20849v1           ["cs"]
# 21  http://arxiv.org/abs/2505.20857v1           ["cs"]
# 22  http://arxiv.org/abs/2505.20842v1        ["astro"]
# 23  http://arxiv.org/abs/2505.20850v1           ["cs"]
# 24  http://arxiv.org/abs/2505.20858v1           ["cs"]
# Processing batch_id: 25 with 20 records.
#                                   aid              predicted_labels
# 0   http://arxiv.org/abs/2505.20860v1                        ["gr"]
# 1   http://arxiv.org/abs/2505.20868v1                ["cs", "eess"]
# 2   http://arxiv.org/abs/2505.20876v1                        ["cs"]
# 3   http://arxiv.org/abs/2505.20861v1                        ["cs"]
# 4   http://arxiv.org/abs/2505.20869v1                        ["cs"]
# 5   http://arxiv.org/abs/2505.20877v1                ["cs", "eess"]
# 6   http://arxiv.org/abs/2505.20862v1                        ["cs"]
# 7   http://arxiv.org/abs/2505.20870v1                      ["eess"]
# 8   http://arxiv.org/abs/2505.20878v1  ["cond", "physics", "quant"]
# 9   http://arxiv.org/abs/2505.20863v1                     ["quant"]
# 10  http://arxiv.org/abs/2505.20871v1                        ["cs"]
# 11  http://arxiv.org/abs/2505.20879v1                        ["cs"]
# 12  http://arxiv.org/abs/2505.20864v1                ["cs", "stat"]
# 13  http://arxiv.org/abs/2505.20872v1                        ["cs"]
# 14  http://arxiv.org/abs/2505.20865v1                ["cs", "math"]
# 15  http://arxiv.org/abs/2505.20873v1                        ["cs"]
# 16  http://arxiv.org/abs/2505.20866v1                        ["cs"]
# 17  http://arxiv.org/abs/2505.20874v1                        ["cs"]
# 18  http://arxiv.org/abs/2505.20867v1                      ["math"]
# 19  http://arxiv.org/abs/2505.20875v1                        ["cs"]
# Processing batch_id: 26 with 20 records.
#                                   aid        predicted_labels
# 0   http://arxiv.org/abs/2505.20880v1                  ["cs"]
# 1   http://arxiv.org/abs/2505.20888v1                  ["cs"]
# 2   http://arxiv.org/abs/2505.20896v1                  ["cs"]
# 3   http://arxiv.org/abs/2505.20881v1                  ["cs"]
# 4   http://arxiv.org/abs/2505.20889v1                  ["cs"]
# 5   http://arxiv.org/abs/2505.20897v1                  ["cs"]
# 6   http://arxiv.org/abs/2505.20882v1                  ["cs"]
# 7   http://arxiv.org/abs/2505.20890v1                  ["cs"]
# 8   http://arxiv.org/abs/2505.20898v1                ["math"]
# 9   http://arxiv.org/abs/2505.20883v1                ["math"]
# 10  http://arxiv.org/abs/2505.20891v1  ["cs", "eess", "math"]
# 11  http://arxiv.org/abs/2505.20899v1          ["cs", "eess"]
# 12  http://arxiv.org/abs/2505.20884v1                  ["cs"]
# 13  http://arxiv.org/abs/2505.20892v1             ["cs", "q"]
# 14  http://arxiv.org/abs/2505.20885v1  ["cs", "math", "stat"]
# 15  http://arxiv.org/abs/2505.20893v1                ["stat"]
# 16  http://arxiv.org/abs/2505.20886v1         ["astro", "gr"]
# 17  http://arxiv.org/abs/2505.20894v1                  ["cs"]
# 18  http://arxiv.org/abs/2505.20887v1                ["eess"]
# 19  http://arxiv.org/abs/2505.20895v1                ["math"]
# Processing batch_id: 27 with 21 records.

# %%
query.stop()
